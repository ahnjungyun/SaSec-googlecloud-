# %%
# !pip install -qq label-studio

# %%
# !pip install -pp PyYAML
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -p

# %%
# !pip install -qq PyYAML torch torchvision torchaudio

# %%
# !pip install -qq ultralytics

# %%
# !pip install -qq torch

# %%
import yaml
import shutil
from ultralytics import YOLO

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data={
    'train': '/content/drive/MyDrive/BT/images/train',
    'val': '/content/drive/MyDrive/BT/images/val',
    "test":'/content/drive/MyDrive/BT/images/test',
    'names' : ["positive","negative"],
    "nc":2
}

# %%
data

# %%
with open('/content/drive/MyDrive/BT/classes.yaml','w') as f:
  yaml.dump(data,f)

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(data="/content/drive/MyDrive/BT/classes.yaml",
            epochs = 100, # 오버피팅발생했음
            conf = 0.5,
            batch = 64,  # 32했을 경우 정확도 부정확
            imgsz = 224)

# %%
srcPath='/content/runs/detect/train2'

# %%
shutil.copytree(srcPath,'/content/drive/MyDrive/BT/runs2')
# Out:
# '/content/drive/MyDrive/BT/runs'
